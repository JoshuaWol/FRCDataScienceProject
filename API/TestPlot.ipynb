# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys


x = np.linspace(0,10,100)
y = np.linspace(0,100,100)

plt.figure()
plt.plot(x,y)
plt.show()
